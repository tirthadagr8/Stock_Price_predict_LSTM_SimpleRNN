# %%
import pandas as pd
import time
from time import sleep
import os,sys
from threading import Thread
#from google.colab import output,drive
import datetime
import matplotlib.pyplot as plt
import numpy as np
import datetime
# !pip install smartapi-python
# !pip install pyotp
# !pip install logzero
# !curl -L http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz -O && tar xzvf ta-lib-0.4.0-src.tar.gz
# !cd ta-lib && ./configure --prefix=/usr && make && make install && cd - && pip install ta-lib
import talib
#os.system('cls')

# %%
from sklearn.preprocessing import StandardScaler

# %%
from SmartApi import SmartConnect #or from SmartApi.smartConnect import SmartConnect
import pyotp

api_key = 'Your_API_Key'
clientId = 'You_Client_Id'
pwd = 'Your_AngelOne_Password'
smartApi = SmartConnect(api_key)
smartApi._routes["api.market.data"]="/rest/secure/angelbroking/market/v1/quote"
token = "Your_TOTP_Token"
totp=pyotp.TOTP(token).now()
correlation_id = "hdhdjdjdjd"

# login api call

data = smartApi.generateSession(clientId, pwd, totp)
# print(data)
authToken = data['data']['jwtToken']
refreshToken = data['data']['refreshToken']

# fetch the feedtoken
feedToken = smartApi.getfeedToken()

# fetch User Profile
res = smartApi.getProfile(refreshToken)
smartApi.generateToken(refreshToken)
res=res['data']['exchanges']

# %%
'''from datetime import datetime,timedelta
import talib
import numpy as np
start=time.time()

def history(historicParam):
    try:
        return smartApi.getCandleData(historicParam)
    except Exception as e:
        print("Historic Api failed: {}".format(e.message))

from datetime import datetime,timedelta,date
import time

t=datetime.now()
#df=datetime(t.year,t.month,t.day,9,15)
t=datetime(t.year,t.month,t.day,t.hour,t.minute)
arr=[]

historicParam={    "exchange": "NSE",
    "symboltoken": "3045",
    "interval": "ONE_MINUTE",
    "fromdate": "",
    "todate": ""
    }
fromdate=datetime(t.year,t.month-2,t.day-1,9,15)
todate=t
#print(fromdate,' ',todate)
historicParam['fromdate']=fromdate.strftime("%Y-%m-%d %H:%M")
historicParam['todate']=todate.strftime("%Y-%m-%d %H:%M")

hist=history(historicParam)
#print(hist)
hist=hist['data']
print(len(hist))
columns=['timestamp','open','high','low','close','volume']
data=pd.DataFrame(hist,columns=columns)
data['timestamp']=pd.to_datetime(data['timestamp'],format="%Y-%m-%d %H:%M")
print(time.time()-start)
'''
output.clear()

# %%
#data.to_csv('SBIN_5_min.csv')

# %%
# merged_data=pd.DataFrame()
# for i in range(30,0,-1):
#     month=pd.read_csv(f'month{i}.csv')
#     merged_data=pd.concat([merged_data,month],ignore_index=True)
# merged_data.to_csv('SBIN_merged_data_1min_interval.csv')

# %%
data=pd.read_csv('SBIN_merged_data_1min_interval.csv')

# %%
data.shape
# Out:
# (37501, 4)

# %%
val={}
Columns=['close']
for col in Columns:
    val[col]=np.array(data[col]).flatten()
ind=np.array(data.index).flatten()
df=pd.DataFrame(val,index=ind)
#sc=StandardScaler()
#df[Columns]=sc.fit_transform(df[Columns])
for i in range(len(df)):
    df['close'][i]=df['close'][i]*0.001

# %%
_7EMA=talib.EMA(np.array(df['close']),7)
_21EMA=talib.EMA(np.array(df['close']),21)

# %%
ax=plt.subplot()
ax.plot(df.index[:100],df['close'][:100])
ax.plot(df.index[:100],_7EMA[:100])
ax.plot(df.index[:100],_21EMA[:100])
ax.legend(['Originial Price Data','7 Exponential Moving Average','21 Exponential Moving Average'])

# %%
ax=plt.subplot()
ax.plot(df.index,df['close'])
ax.plot(df.index,_7EMA)
ax.plot(df.index,_21EMA)
ax.legend(['Originial Price Data','7 Exponential Moving Average','21 Exponential Moving Average'])

# %%
'''ax=plt.subplot()
ax.plot(df.time,df['close'])
ax.plot(df.time,df['7EMA'])
ax.plot(df.time,df['21EMA'])
ax.legend(['Originial Price Data','7 Exponential Moving Average','21 Exponential Moving Average'])'''
# Out:
# "ax=plt.subplot()\nax.plot(df.time,df['close'])\nax.plot(df.time,df['7EMA'])\nax.plot(df.time,df['21EMA'])\nax.legend(['Originial Price Data','7 Exponential Moving Average','21 Exponential Moving Average'])"

# %%
temp=df.copy()
df=temp.copy()

# %%
temp.head()
# Out:
#      close
# 0  0.52140
# 1  0.52225
# 2  0.52215
# 3  0.52225
# 4  0.52130

# %%
df=temp.copy()

# %%
n=5
df=temp.copy()
tf=pd.DataFrame()
Temp=np.array(df['close']).flatten()
#tf['open']=[]
for i in range(n):
    tf[f'close{i+1}']=[]
tf['close']=[]
coltf=np.array(tf.columns).flatten()
print(coltf)
for i in range(n,len(df)):
    #print(i)
    point={}
    #point['open']=df['open'][i]
    cl=Temp[i-n:i+1]
    #print('cl:',str(cl))
    for j in range(n+1):
        point[coltf[j]]=cl[j]
        #print('j:',j)
    #print('IN')
    #point['close']=df['close'][i]
    #print(point)
    point=pd.DataFrame(point,index=[1])
    tf=pd.concat([tf,point],ignore_index=True)
    #tf=tf.reset_index(drop=True)
df=tf.copy()
# Out:
# ['close1' 'close2' 'close3' 'close4' 'close5' 'close']

# %%
_7EMA=_7EMA[n:]
_21EMA=_21EMA[n:]

# %%
#df=df[800:]
#df=df.reset_index(drop=True)
df.head()
# Out:
#     close1   close2   close3   close4   close5    close
# 0  0.52140  0.52225  0.52215  0.52225  0.52130  0.52105
# 1  0.52225  0.52215  0.52225  0.52130  0.52105  0.52090
# 2  0.52215  0.52225  0.52130  0.52105  0.52090  0.52180
# 3  0.52225  0.52130  0.52105  0.52090  0.52180  0.52250
# 4  0.52130  0.52105  0.52090  0.52180  0.52250  0.52280

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates=df.index#df_as_np[:,0]
    middle_matrix=df_as_np[:,:-1]
    X=middle_matrix.reshape((len(dates),middle_matrix.shape[1],1))
    Y = df_as_np[:, -1]

    return dates, X.astype(np.float32), Y.astype(np.float32)
dates, X, y = windowed_df_to_date_X_y(df)

# %%
dates.shape, X.shape, y.shape
# Out:
# ((37496,), (37496, 5, 1), (37496,))

# %%
q_80=int(len(dates)*0.8)
q_90=int(len(dates)*0.9)

dates_train,X_train,y_train=dates[:q_80],X[:q_80],y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %% [markdown]
# Now LSTM model training start

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM,Dense,Dropout

'''model=Sequential([
    layers.Dense(64,input_shape=(4,1)),        ## '64' is the number of units(neurons) and is necessary for dense layers
    layers.LSTM(32),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    #layers.Dense(256, activation='relu'),
    layers.Dense(1)
])
'''

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (n,1)))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(1))

#model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()


model.compile(loss='mse',optimizer=Adam(learning_rate=0.001),metrics=['mean_absolute_error'])

model.fit(X_train,y_train,validation_data=(X_val,y_val),epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 50)             10400
#
#  dropout (Dropout)           (None, 5, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30651 (119.73 KB)
# Trainable params: 30651 (119.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 938/938 [==============================] - 18s 13ms/step - loss: 0.0039 - mean_absolute_error: 0.0217 - val_loss: 5.4189e-05 - val_mean_absolute_error: 0.0065
# Epoch 2/100
# 938/938 [==============================] - 11s 12ms/step - loss: 1.3356e-04 - mean_absolute_error: 0.0091 - val_loss: 1.6953e-05 - val_mean_absolute_error: 0.0036
# Epoch 3/100
# 938/938 [==============================] - 12s 12ms/step - loss: 5.4754e-05 - mean_absolute_error: 0.0058 - val_loss: 2.9234e-06 - val_mean_absolute_error: 0.0016
# Epoch 4/100
# 938/938 [==============================] - 14s 15ms/step - loss: 1.6409e-05 - mean_absolute_error: 0.0032 - val_loss: 4.8883e-07 - val_mean_absolute_error: 4.7471e-04
# Epoch 5/100
# 938/938 [==============================] - 19s 20ms/step - loss: 5.4261e-06 - mean_absolute_error: 0.0019 - val_loss: 4.9534e-06 - val_mean_absolute_error: 0.0021
# Epoch 6/100
# 938/938 [==============================] - 25s 26ms/step - loss: 3.7936e-06 - mean_absolute_error: 0.0015 - val_loss: 4.9896e-06 - val_mean_absolute_error: 0.0021
# Epoch 7/100
# 938/938 [==============================] - 25s 26ms/step - loss: 3.5971e-06 - mean_absolute_error: 0.0015 - val_loss: 2.1138e-06 - val_mean_absolute_error: 0.0013
# Epoch 8/100
# 938/938 [==============================] - 25s 26ms/step - loss: 3.5964e-06 - mean_absolute_error: 0.0015 - val_loss: 9.2576e-07 - val_mean_absolute_error: 7.7693e-04
# Epoch 9/100
# 938/938 [==============================] - 23s 25ms/step - loss: 3.3697e-06 - mean_absolute_error: 0.0015 - val_loss: 9.8069e-06 - val_mean_absolute_error: 0.0030
# Epoch 10/100
# 938/938 [==============================] - 14s 15ms/step - loss: 3.3038e-06 - mean_absolute_error: 0.0014 - val_loss: 9.9680e-07 - val_mean_absolute_error: 7.6727e-04
# Epoch 11/100
# 938/938 [==============================] - 13s 13ms/step - loss: 3.5737e-06 - mean_absolute_error: 0.0015 - val_loss: 2.1626e-06 - val_mean_absolute_error: 0.0014
# Epoch 12/100
# 938/938 [==============================] - 15s 16ms/step - loss: 3.0611e-06 - mean_absolute_error: 0.0014 - val_loss: 5.0475e-07 - val_mean_absolute_error: 4.8780e-04
# Epoch 13/100
# 938/938 [==============================] - 16s 17ms/step - loss: 3.0763e-06 - mean_absolute_error: 0.0014 - val_loss: 3.8435e-06 - val_mean_absolute_error: 0.0019
# Epoch 14/100
# 938/938 [==============================] - 19s 20ms/step - loss: 3.0013e-06 - mean_absolute_error: 0.0014 - val_loss: 1.5550e-06 - val_mean_absolute_error: 0.0011
# Epoch 15/100
# 938/938 [==============================] - 16s 17ms/step - loss: 3.0505e-06 - mean_absolute_error: 0.0014 - val_loss: 1.2422e-05 - val_mean_absolute_error: 0.0034
# Epoch 16/100
# 938/938 [==============================] - 15s 15ms/step - loss: 2.8542e-06 - mean_absolute_error: 0.0013 - val_loss: 4.4048e-06 - val_mean_absolute_error: 0.0020
# Epoch 17/100
# 938/938 [==============================] - 14s 15ms/step - loss: 2.9982e-06 - mean_absolute_error: 0.0014 - val_loss: 1.3749e-06 - val_mean_absolute_error: 9.9751e-04
# Epoch 18/100
# 938/938 [==============================] - 12s 13ms/step - loss: 2.6870e-06 - mean_absolute_error: 0.0013 - val_loss: 5.2889e-07 - val_mean_absolute_error: 5.3047e-04
# Epoch 19/100
# 938/938 [==============================] - 10s 11ms/step - loss: 2.3332e-06 - mean_absolute_error: 0.0012 - val_loss: 5.8707e-06 - val_mean_absolute_error: 0.0023
# Epoch 20/100
# 938/938 [==============================] - 11s 12ms/step - loss: 2.6717e-06 - mean_absolute_error: 0.0013 - val_loss: 2.3721e-06 - val_mean_absolute_error: 0.0014
# Epoch 21/100
# 938/938 [==============================] - 11s 12ms/step - loss: 2.4821e-06 - mean_absolute_error: 0.0012 - val_loss: 4.6036e-07 - val_mean_absolute_error: 4.7110e-04
# Epoch 22/100
# 938/938 [==============================] - 12s 13ms/step - loss: 2.8584e-06 - mean_absolute_error: 0.0013 - val_loss: 8.1537e-06 - val_mean_absolute_error: 0.0028
# Epoch 23/100
# 938/938 [==============================] - 11s 12ms/step - loss: 2.1676e-06 - mean_absolute_error: 0.0011 - val_loss: 1.2306e-06 - val_mean_absolute_error: 9.7938e-04
# Epoch 24/100
# 938/938 [==============================] - 12s 12ms/step - loss: 2.7244e-06 - mean_absolute_error: 0.0013 - val_loss: 5.4295e-06 - val_mean_absolute_error: 0.0022
# Epoch 25/100
# 938/938 [==============================] - 12s 12ms/step - loss: 2.2383e-06 - mean_absolute_error: 0.0012 - val_loss: 2.2327e-06 - val_mean_absolute_error: 0.0014
# Epoch 26/100
# 938/938 [==============================] - 11s 12ms/step - loss: 2.6112e-06 - mean_absolute_error: 0.0013 - val_loss: 6.4445e-07 - val_mean_absolute_error: 5.9622e-04
# Epoch 27/100
# 938/938 [==============================] - 12s 12ms/step - loss: 2.4503e-06 - mean_absolute_error: 0.0012 - val_loss: 5.7487e-06 - val_mean_absolute_error: 0.0023
# Epoch 28/100
# 938/938 [==============================] - 11s 12ms/step - loss: 2.2507e-06 - mean_absolute_error: 0.0012 - val_loss: 5.5774e-07 - val_mean_absolute_error: 5.4004e-04
# Epoch 29/100
# 938/938 [==============================] - 11s 12ms/step - loss: 2.2695e-06 - mean_absolute_error: 0.0012 - val_loss: 2.2160e-06 - val_mean_absolute_error: 0.0014
# Epoch 30/100
# 938/938 [==============================] - 11s 11ms/step - loss: 2.1750e-06 - mean_absolute_error: 0.0012 - val_loss: 3.0990e-06 - val_mean_absolute_error: 0.0017
# Epoch 31/100
# 938/938 [==============================] - 11s 12ms/step - loss: 2.2172e-06 - mean_absolute_error: 0.0011 - val_loss: 6.7215e-06 - val_mean_absolute_error: 0.0025
# Epoch 32/100
# 938/938 [==============================] - 11s 12ms/step - loss: 2.4244e-06 - mean_absolute_error: 0.0012 - val_loss: 8.1475e-07 - val_mean_absolute_error: 6.9251e-04
# Epoch 33/100
# 938/938 [==============================] - 11s 11ms/step - loss: 2.0503e-06 - mean_absolute_error: 0.0011 - val_loss: 5.8926e-07 - val_mean_absolute_error: 6.0509e-04
# Epoch 34/100
# 938/938 [==============================] - 13s 14ms/step - loss: 2.0411e-06 - mean_absolute_error: 0.0011 - val_loss: 6.1009e-07 - val_mean_absolute_error: 5.8281e-04
# Epoch 35/100
# 938/938 [==============================] - 12s 12ms/step - loss: 2.0393e-06 - mean_absolute_error: 0.0011 - val_loss: 1.2316e-06 - val_mean_absolute_error: 9.5615e-04
# Epoch 36/100
# 938/938 [==============================] - 13s 14ms/step - loss: 2.3044e-06 - mean_absolute_error: 0.0012 - val_loss: 2.5561e-06 - val_mean_absolute_error: 0.0015
# Epoch 37/100
# 938/938 [==============================] - 10s 11ms/step - loss: 1.9375e-06 - mean_absolute_error: 0.0011 - val_loss: 8.6628e-07 - val_mean_absolute_error: 7.4634e-04
# Epoch 38/100
# 938/938 [==============================] - 10s 11ms/step - loss: 2.2368e-06 - mean_absolute_error: 0.0012 - val_loss: 4.6122e-07 - val_mean_absolute_error: 4.9426e-04
# Epoch 39/100
# 938/938 [==============================] - 13s 13ms/step - loss: 2.0324e-06 - mean_absolute_error: 0.0011 - val_loss: 4.6960e-06 - val_mean_absolute_error: 0.0021
# Epoch 40/100
# 938/938 [==============================] - 12s 13ms/step - loss: 2.0560e-06 - mean_absolute_error: 0.0011 - val_loss: 5.5865e-06 - val_mean_absolute_error: 0.0023
# Epoch 41/100
# 938/938 [==============================] - 16s 17ms/step - loss: 2.1470e-06 - mean_absolute_error: 0.0012 - val_loss: 1.1154e-06 - val_mean_absolute_error: 9.0098e-04
# Epoch 42/100
# 938/938 [==============================] - 17s 18ms/step - loss: 1.9072e-06 - mean_absolute_error: 0.0011 - val_loss: 7.3125e-06 - val_mean_absolute_error: 0.0026
# Epoch 43/100
# 938/938 [==============================] - 18s 19ms/step - loss: 1.9154e-06 - mean_absolute_error: 0.0011 - val_loss: 2.0603e-06 - val_mean_absolute_error: 0.0013
# Epoch 44/100
# 938/938 [==============================] - 19s 20ms/step - loss: 1.8274e-06 - mean_absolute_error: 0.0011 - val_loss: 5.0456e-07 - val_mean_absolute_error: 5.3731e-04
# Epoch 45/100
# 938/938 [==============================] - 16s 18ms/step - loss: 1.9686e-06 - mean_absolute_error: 0.0011 - val_loss: 8.7923e-07 - val_mean_absolute_error: 7.5805e-04
# Epoch 46/100
# 938/938 [==============================] - 16s 17ms/step - loss: 2.0254e-06 - mean_absolute_error: 0.0011 - val_loss: 5.3524e-07 - val_mean_absolute_error: 5.7400e-04
# Epoch 47/100
# 938/938 [==============================] - 15s 16ms/step - loss: 1.5364e-06 - mean_absolute_error: 9.7531e-04 - val_loss: 1.2419e-06 - val_mean_absolute_error: 9.8246e-04
# Epoch 48/100
# 938/938 [==============================] - 12s 13ms/step - loss: 1.9316e-06 - mean_absolute_error: 0.0011 - val_loss: 1.4014e-06 - val_mean_absolute_error: 0.0011
# Epoch 49/100
# 938/938 [==============================] - 14s 15ms/step - loss: 1.9304e-06 - mean_absolute_error: 0.0011 - val_loss: 2.1976e-06 - val_mean_absolute_error: 0.0014
# Epoch 50/100
# 938/938 [==============================] - 22s 23ms/step - loss: 1.8082e-06 - mean_absolute_error: 0.0011 - val_loss: 6.2184e-07 - val_mean_absolute_error: 6.0947e-04
# Epoch 51/100
# 938/938 [==============================] - 17s 18ms/step - loss: 1.7637e-06 - mean_absolute_error: 0.0010 - val_loss: 6.0385e-07 - val_mean_absolute_error: 5.9552e-04
# Epoch 52/100
# 938/938 [==============================] - 19s 21ms/step - loss: 1.6478e-06 - mean_absolute_error: 0.0010 - val_loss: 9.5917e-07 - val_mean_absolute_error: 8.3517e-04
# Epoch 53/100
# 938/938 [==============================] - 16s 17ms/step - loss: 1.7339e-06 - mean_absolute_error: 0.0010 - val_loss: 4.3578e-07 - val_mean_absolute_error: 4.6436e-04
# Epoch 54/100
# 938/938 [==============================] - 18s 19ms/step - loss: 1.8384e-06 - mean_absolute_error: 0.0011 - val_loss: 1.8731e-06 - val_mean_absolute_error: 0.0013
# Epoch 55/100
# 938/938 [==============================] - 12s 13ms/step - loss: 1.6925e-06 - mean_absolute_error: 0.0010 - val_loss: 3.8525e-07 - val_mean_absolute_error: 4.3886e-04
# Epoch 56/100
# 938/938 [==============================] - 12s 13ms/step - loss: 1.7937e-06 - mean_absolute_error: 0.0011 - val_loss: 4.5060e-07 - val_mean_absolute_error: 5.0433e-04
# Epoch 57/100
# 938/938 [==============================] - 26s 27ms/step - loss: 1.6017e-06 - mean_absolute_error: 9.8413e-04 - val_loss: 3.8637e-07 - val_mean_absolute_error: 4.2304e-04
# Epoch 58/100
# 938/938 [==============================] - 18s 19ms/step - loss: 1.7585e-06 - mean_absolute_error: 0.0010 - val_loss: 8.3027e-07 - val_mean_absolute_error: 7.1152e-04
# Epoch 59/100
# 938/938 [==============================] - 15s 16ms/step - loss: 1.6415e-06 - mean_absolute_error: 0.0010 - val_loss: 1.4746e-06 - val_mean_absolute_error: 0.0011
# Epoch 60/100
# 938/938 [==============================] - 12s 13ms/step - loss: 1.5644e-06 - mean_absolute_error: 9.8150e-04 - val_loss: 3.9559e-07 - val_mean_absolute_error: 4.3384e-04
# Epoch 61/100
# 938/938 [==============================] - 18s 19ms/step - loss: 1.6491e-06 - mean_absolute_error: 0.0010 - val_loss: 3.7929e-06 - val_mean_absolute_error: 0.0018
# Epoch 62/100
# 938/938 [==============================] - 15s 16ms/step - loss: 1.6922e-06 - mean_absolute_error: 0.0010 - val_loss: 1.7962e-06 - val_mean_absolute_error: 0.0012
# Epoch 63/100
# 938/938 [==============================] - 19s 20ms/step - loss: 1.7289e-06 - mean_absolute_error: 0.0010 - val_loss: 7.9655e-06 - val_mean_absolute_error: 0.0028
# Epoch 64/100
# 938/938 [==============================] - 18s 19ms/step - loss: 1.6368e-06 - mean_absolute_error: 0.0010 - val_loss: 8.9034e-07 - val_mean_absolute_error: 8.1165e-04
# Epoch 65/100
# 938/938 [==============================] - 18s 19ms/step - loss: 1.8122e-06 - mean_absolute_error: 0.0010 - val_loss: 1.9703e-06 - val_mean_absolute_error: 0.0013
# Epoch 66/100
# 938/938 [==============================] - 22s 24ms/step - loss: 1.4260e-06 - mean_absolute_error: 9.3146e-04 - val_loss: 6.0956e-07 - val_mean_absolute_error: 6.0752e-04
# Epoch 67/100
# 938/938 [==============================] - 13s 14ms/step - loss: 1.7672e-06 - mean_absolute_error: 0.0010 - val_loss: 1.0800e-06 - val_mean_absolute_error: 8.3609e-04
# Epoch 68/100
# 938/938 [==============================] - 17s 18ms/step - loss: 1.5407e-06 - mean_absolute_error: 9.6934e-04 - val_loss: 3.2741e-07 - val_mean_absolute_error: 3.7721e-04
# Epoch 69/100
# 938/938 [==============================] - 21s 22ms/step - loss: 1.5247e-06 - mean_absolute_error: 9.6689e-04 - val_loss: 4.3543e-07 - val_mean_absolute_error: 4.9621e-04
# Epoch 70/100
# 938/938 [==============================] - 25s 26ms/step - loss: 1.3786e-06 - mean_absolute_error: 9.2077e-04 - val_loss: 3.2649e-07 - val_mean_absolute_error: 3.7557e-04
# Epoch 71/100
# 938/938 [==============================] - 24s 26ms/step - loss: 1.6404e-06 - mean_absolute_error: 0.0010 - val_loss: 2.2516e-06 - val_mean_absolute_error: 0.0014
# Epoch 72/100
# 938/938 [==============================] - 19s 21ms/step - loss: 1.5717e-06 - mean_absolute_error: 9.8314e-04 - val_loss: 6.0624e-07 - val_mean_absolute_error: 6.0539e-04
# Epoch 73/100
# 938/938 [==============================] - 13s 14ms/step - loss: 1.4437e-06 - mean_absolute_error: 9.4091e-04 - val_loss: 1.3257e-06 - val_mean_absolute_error: 9.7056e-04
# Epoch 74/100
# 938/938 [==============================] - 13s 13ms/step - loss: 1.5878e-06 - mean_absolute_error: 9.8349e-04 - val_loss: 4.5179e-06 - val_mean_absolute_error: 0.0020
# Epoch 75/100
# 938/938 [==============================] - 13s 14ms/step - loss: 1.3549e-06 - mean_absolute_error: 9.1278e-04 - val_loss: 3.5528e-06 - val_mean_absolute_error: 0.0018
# Epoch 76/100
# 938/938 [==============================] - 15s 16ms/step - loss: 1.5831e-06 - mean_absolute_error: 9.9126e-04 - val_loss: 1.6292e-06 - val_mean_absolute_error: 0.0012
# Epoch 77/100
# 938/938 [==============================] - 16s 18ms/step - loss: 1.4115e-06 - mean_absolute_error: 9.2593e-04 - val_loss: 5.4192e-07 - val_mean_absolute_error: 5.6110e-04
# Epoch 78/100
# 938/938 [==============================] - 15s 16ms/step - loss: 1.3737e-06 - mean_absolute_error: 9.1926e-04 - val_loss: 2.0401e-06 - val_mean_absolute_error: 0.0013
# Epoch 79/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.6148e-06 - mean_absolute_error: 0.0010 - val_loss: 6.2293e-06 - val_mean_absolute_error: 0.0024
# Epoch 80/100
# 938/938 [==============================] - 24s 25ms/step - loss: 1.5622e-06 - mean_absolute_error: 9.8168e-04 - val_loss: 2.0347e-06 - val_mean_absolute_error: 0.0013
# Epoch 81/100
# 938/938 [==============================] - 26s 28ms/step - loss: 1.3300e-06 - mean_absolute_error: 8.9015e-04 - val_loss: 3.5001e-07 - val_mean_absolute_error: 4.1423e-04
# Epoch 82/100
# 938/938 [==============================] - 26s 28ms/step - loss: 1.5343e-06 - mean_absolute_error: 9.6971e-04 - val_loss: 4.8438e-07 - val_mean_absolute_error: 5.0948e-04
# Epoch 83/100
# 938/938 [==============================] - 26s 28ms/step - loss: 1.3667e-06 - mean_absolute_error: 9.1981e-04 - val_loss: 4.3434e-06 - val_mean_absolute_error: 0.0020
# Epoch 84/100
# 938/938 [==============================] - 25s 27ms/step - loss: 1.3413e-06 - mean_absolute_error: 8.9549e-04 - val_loss: 1.3986e-06 - val_mean_absolute_error: 0.0011
# Epoch 85/100
# 938/938 [==============================] - 19s 20ms/step - loss: 1.4416e-06 - mean_absolute_error: 9.4043e-04 - val_loss: 4.3710e-06 - val_mean_absolute_error: 0.0020
# Epoch 86/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.4695e-06 - mean_absolute_error: 9.4262e-04 - val_loss: 2.4660e-06 - val_mean_absolute_error: 0.0015
# Epoch 87/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.3526e-06 - mean_absolute_error: 9.1084e-04 - val_loss: 4.8192e-07 - val_mean_absolute_error: 5.1634e-04
# Epoch 88/100
# 938/938 [==============================] - 21s 22ms/step - loss: 1.3655e-06 - mean_absolute_error: 9.2276e-04 - val_loss: 1.0110e-06 - val_mean_absolute_error: 8.6629e-04
# Epoch 89/100
# 938/938 [==============================] - 22s 24ms/step - loss: 1.4767e-06 - mean_absolute_error: 9.4765e-04 - val_loss: 1.4613e-06 - val_mean_absolute_error: 0.0011
# Epoch 90/100
# 938/938 [==============================] - 21s 22ms/step - loss: 1.4555e-06 - mean_absolute_error: 9.3467e-04 - val_loss: 3.7369e-07 - val_mean_absolute_error: 4.4327e-04
# Epoch 91/100
# 938/938 [==============================] - 20s 21ms/step - loss: 1.4664e-06 - mean_absolute_error: 9.3351e-04 - val_loss: 3.2300e-07 - val_mean_absolute_error: 3.8739e-04
# Epoch 92/100
# 938/938 [==============================] - 24s 25ms/step - loss: 1.3844e-06 - mean_absolute_error: 9.1532e-04 - val_loss: 6.4498e-07 - val_mean_absolute_error: 6.4158e-04
# Epoch 93/100
# 938/938 [==============================] - 22s 23ms/step - loss: 1.3149e-06 - mean_absolute_error: 8.9223e-04 - val_loss: 5.0356e-07 - val_mean_absolute_error: 5.3760e-04
# Epoch 94/100
# 938/938 [==============================] - 22s 23ms/step - loss: 1.1626e-06 - mean_absolute_error: 8.4306e-04 - val_loss: 1.6345e-06 - val_mean_absolute_error: 0.0012
# Epoch 95/100
# 938/938 [==============================] - 22s 23ms/step - loss: 1.2914e-06 - mean_absolute_error: 8.8487e-04 - val_loss: 1.8885e-06 - val_mean_absolute_error: 0.0013
# Epoch 96/100
# 938/938 [==============================] - 21s 22ms/step - loss: 1.2436e-06 - mean_absolute_error: 8.6887e-04 - val_loss: 1.6740e-06 - val_mean_absolute_error: 0.0012
# Epoch 97/100
# 938/938 [==============================] - 24s 26ms/step - loss: 1.3385e-06 - mean_absolute_error: 9.0011e-04 - val_loss: 3.0806e-07 - val_mean_absolute_error: 3.7405e-04
# Epoch 98/100
# 938/938 [==============================] - 22s 23ms/step - loss: 1.3265e-06 - mean_absolute_error: 9.0161e-04 - val_loss: 2.1875e-06 - val_mean_absolute_error: 0.0014
# Epoch 99/100
# 938/938 [==============================] - 12s 13ms/step - loss: 1.2817e-06 - mean_absolute_error: 8.8775e-04 - val_loss: 3.5263e-07 - val_mean_absolute_error: 4.2734e-04
# Epoch 100/100
# 938/938 [==============================] - 10s 11ms/step - loss: 1.3141e-06 - mean_absolute_error: 8.9045e-04 - val_loss: 2.9896e-07 - val_mean_absolute_error: 3.6078e-04

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 938/938 [==============================] - 7s 6ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 118/118 [==============================] - 1s 5ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 118/118 [==============================] - 1s 6ms/step

# %%
print(y_test.shape,' ',test_predictions.shape)
y_test=np.array(y_test).flatten()
test_predictions=np.array(test_predictions).flatten()
from sklearn.metrics import mean_squared_error as mse,accuracy_score, f1_score
sum=0
for i in range(len(y_test)):
    sum+=abs(y_test[i]-test_predictions[i])
sum=sum/len(y_test)
print((1-sum*100)*100)
# Out:
# (3750,)   (3750,)
# 97.07492558161418

# %% [markdown]
# CALCULATING EMA based on Predicted 'close' Values

# %%
pred_7EMA=[]
pred_21EMA=[]
prev_EMA=_7EMA[dates_test[0]-1]
for i in range(len(dates_test)):
    pred_7EMA.append(0.25*test_predictions[i]+prev_EMA*0.75)
    prev_EMA=pred_7EMA[-1]
prev_EMA=_21EMA[dates_test[0]-1]
for i in range(len(dates_test)):
    pred_21EMA.append((2/22.0)*test_predictions[i]+prev_EMA*(1-2/22))
    prev_EMA=pred_21EMA[-1]

# %%
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(dates_test,pred_7EMA)
plt.plot(dates_test,pred_21EMA)
plt.legend(['Testing Predictions', 'Testing Observations','Predicted 7EMA','Predicted 21EMA'])

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import Sequential, model_from_json
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk
