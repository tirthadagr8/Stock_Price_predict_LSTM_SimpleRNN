# %%
import pandas as pd
import time
from time import sleep
import os,sys
from threading import Thread
from google.colab import output,drive
import datetime
import matplotlib.pyplot as plt
import numpy as np
import datetime
# !pip install smartapi-python
# !pip install pyotp
# !pip install logzero
# !curl -L http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz -O && tar xzvf ta-lib-0.4.0-src.tar.gz
# !cd ta-lib && ./configure --prefix=/usr && make && make install && cd - && pip install ta-lib
import talib
output.clear()

# %%
from sklearn.preprocessing import StandardScaler

# %%
from SmartApi import SmartConnect #or from SmartApi.smartConnect import SmartConnect
import pyotp

api_key = 'Your_API_Key'
clientId = 'You_Client_Id'
pwd = 'Your_AngelOne_Password'
smartApi = SmartConnect(api_key)
smartApi._routes["api.market.data"]="/rest/secure/angelbroking/market/v1/quote"
token = "Your_TOTP_Token"
totp=pyotp.TOTP(token).now()
correlation_id = "hdhdjdjdjd"

# login api call

data = smartApi.generateSession(clientId, pwd, totp)
# print(data)
authToken = data['data']['jwtToken']
refreshToken = data['data']['refreshToken']

# fetch the feedtoken
feedToken = smartApi.getfeedToken()

# fetch User Profile
res = smartApi.getProfile(refreshToken)
smartApi.generateToken(refreshToken)
res=res['data']['exchanges']

# %%
'''from datetime import datetime,timedelta
import talib
import numpy as np
start=time.time()

def history(historicParam):
    try:
        return smartApi.getCandleData(historicParam)
    except Exception as e:
        print("Historic Api failed: {}".format(e.message))

from datetime import datetime,timedelta,date
import time

t=datetime.now()
#df=datetime(t.year,t.month,t.day,9,15)
t=datetime(t.year,t.month,t.day,t.hour,t.minute)
arr=[]

historicParam={    "exchange": "NSE",
    "symboltoken": "3045",
    "interval": "ONE_MINUTE",
    "fromdate": "",
    "todate": ""
    }
fromdate=datetime(t.year,t.month-2,t.day-1,9,15)
todate=t
#print(fromdate,' ',todate)
historicParam['fromdate']=fromdate.strftime("%Y-%m-%d %H:%M")
historicParam['todate']=todate.strftime("%Y-%m-%d %H:%M")

hist=history(historicParam)
#print(hist)
hist=hist['data']
print(len(hist))
columns=['timestamp','open','high','low','close','volume']
data=pd.DataFrame(hist,columns=columns)
data['timestamp']=pd.to_datetime(data['timestamp'],format="%Y-%m-%d %H:%M")
print(time.time()-start)
'''
output.clear()

# %%
#data.to_csv('SBIN_5_min.csv')

# %%
merged_data=pd.DataFrame()
for i in range(30,0,-1):
    month=pd.read_csv(f'month{i}.csv')
    merged_data=pd.concat([merged_data,month],ignore_index=True)
merged_data.to_csv('SBIN_merged_data_1min_interval.csv')

# %%
merged_data.shape
# Out:
# (37501, 3)

# %%
data=pd.read_csv('SBIN_merged_data_1min_interval.csv')

# %%
val={}
Columns=['close']
for col in Columns:
    val[col]=np.array(data[col]).flatten()
ind=np.array(data.index).flatten()
df=pd.DataFrame(val,index=ind)
#sc=StandardScaler()
#df[Columns]=sc.fit_transform(df[Columns])
for i in range(len(df)):
    df['close'][i]=df['close'][i]*0.001

# %%
_7EMA=talib.EMA(np.array(df['close']),7)
_21EMA=talib.EMA(np.array(df['close']),21)

# %%
ax=plt.subplot()
ax.plot(df.index[:100],df['close'][:100])
ax.plot(df.index[:100],_7EMA[:100])
ax.plot(df.index[:100],_21EMA[:100])
ax.legend(['Originial Price Data','7 Exponential Moving Average','21 Exponential Moving Average'])

# %%
ax=plt.subplot()
ax.plot(df.index,df['close'])
ax.plot(df.index,_7EMA)
ax.plot(df.index,_21EMA)
ax.legend(['Originial Price Data','7 Exponential Moving Average','21 Exponential Moving Average'])

# %%
'''ax=plt.subplot()
ax.plot(df.time,df['close'])
ax.plot(df.time,df['7EMA'])
ax.plot(df.time,df['21EMA'])
ax.legend(['Originial Price Data','7 Exponential Moving Average','21 Exponential Moving Average'])'''
# Out:
# "ax=plt.subplot()\nax.plot(df.time,df['close'])\nax.plot(df.time,df['7EMA'])\nax.plot(df.time,df['21EMA'])\nax.legend(['Originial Price Data','7 Exponential Moving Average','21 Exponential Moving Average'])"

# %%
temp=df.copy()
df=temp.copy()

# %%
temp.head()
# Out:
#      close
# 0  0.52140
# 1  0.52225
# 2  0.52215
# 3  0.52225
# 4  0.52130

# %%
df=temp.copy()

# %%
n=5
df=temp.copy()
tf=pd.DataFrame()
Temp=np.array(df['close']).flatten()
#tf['open']=[]
for i in range(n):
    tf[f'close{i+1}']=[]
tf['close']=[]
coltf=np.array(tf.columns).flatten()
print(coltf)
for i in range(n,len(df)):
    #print(i)
    point={}
    #point['open']=df['open'][i]
    cl=Temp[i-n:i+1]
    #print('cl:',str(cl))
    for j in range(n+1):
        point[coltf[j]]=cl[j]
        #print('j:',j)
    #print('IN')
    #point['close']=df['close'][i]
    #print(point)
    point=pd.DataFrame(point,index=[1])
    tf=pd.concat([tf,point],ignore_index=True)
    #tf=tf.reset_index(drop=True)
df=tf.copy()
# Out:
# ['close1' 'close2' 'close3' 'close4' 'close5' 'close']

# %%
_7EMA=_7EMA[n:]
_21EMA=_21EMA[n:]

# %%
#df=df[800:]
#df=df.reset_index(drop=True)
df.head()
# Out:
#     close1   close2   close3   close4   close5    close
# 0  0.52140  0.52225  0.52215  0.52225  0.52130  0.52105
# 1  0.52225  0.52215  0.52225  0.52130  0.52105  0.52090
# 2  0.52215  0.52225  0.52130  0.52105  0.52090  0.52180
# 3  0.52225  0.52130  0.52105  0.52090  0.52180  0.52250
# 4  0.52130  0.52105  0.52090  0.52180  0.52250  0.52280

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates=df.index#df_as_np[:,0]
    middle_matrix=df_as_np[:,:-1]
    X=middle_matrix.reshape((len(dates),middle_matrix.shape[1],1))
    Y = df_as_np[:, -1]

    return dates, X.astype(np.float32), Y.astype(np.float32)
dates, X, y = windowed_df_to_date_X_y(df)

# %%
dates.shape, X.shape, y.shape
# Out:
# ((37496,), (37496, 5, 1), (37496,))

# %%
q_80=int(len(dates)*0.8)
q_90=int(len(dates)*0.9)

dates_train,X_train,y_train=dates[:q_80],X[:q_80],y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %% [markdown]
# Now LSTM model training start

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM,Dense,Dropout

'''model=Sequential([
    layers.Dense(64,input_shape=(4,1)),        ## '64' is the number of units(neurons) and is necessary for dense layers
    layers.LSTM(32),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    #layers.Dense(256, activation='relu'),
    layers.Dense(1)
])
'''

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (n,1)))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(1))

#model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()


model.compile(loss='mse',optimizer=Adam(learning_rate=0.001),metrics=['mean_absolute_error'])

model.fit(X_train,y_train,validation_data=(X_val,y_val),epochs=100)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 50)             10400
#
#  dropout (Dropout)           (None, 5, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 938/938 [==============================] - 16s 8ms/step - loss: 0.0031 - mean_absolute_error: 0.0207 - val_loss: 1.7749e-04 - val_mean_absolute_error: 0.0113
# Epoch 2/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.4509e-04 - mean_absolute_error: 0.0096 - val_loss: 3.0539e-05 - val_mean_absolute_error: 0.0049
# Epoch 3/100
# 938/938 [==============================] - 6s 7ms/step - loss: 6.1794e-05 - mean_absolute_error: 0.0062 - val_loss: 2.6280e-05 - val_mean_absolute_error: 0.0050
# Epoch 4/100
# 938/938 [==============================] - 7s 7ms/step - loss: 1.9676e-05 - mean_absolute_error: 0.0035 - val_loss: 8.9741e-07 - val_mean_absolute_error: 7.4534e-04
# Epoch 5/100
# 938/938 [==============================] - 6s 7ms/step - loss: 7.5113e-06 - mean_absolute_error: 0.0022 - val_loss: 1.2937e-06 - val_mean_absolute_error: 9.8170e-04
# Epoch 6/100
# 938/938 [==============================] - 7s 7ms/step - loss: 4.4010e-06 - mean_absolute_error: 0.0017 - val_loss: 1.6983e-06 - val_mean_absolute_error: 0.0011
# Epoch 7/100
# 938/938 [==============================] - 6s 7ms/step - loss: 3.8196e-06 - mean_absolute_error: 0.0015 - val_loss: 1.0069e-05 - val_mean_absolute_error: 0.0031
# Epoch 8/100
# 938/938 [==============================] - 7s 7ms/step - loss: 3.9310e-06 - mean_absolute_error: 0.0016 - val_loss: 4.3101e-06 - val_mean_absolute_error: 0.0019
# Epoch 9/100
# 938/938 [==============================] - 6s 6ms/step - loss: 3.8267e-06 - mean_absolute_error: 0.0016 - val_loss: 3.4007e-06 - val_mean_absolute_error: 0.0017
# Epoch 10/100
# 938/938 [==============================] - 7s 8ms/step - loss: 3.9939e-06 - mean_absolute_error: 0.0016 - val_loss: 1.3869e-06 - val_mean_absolute_error: 0.0010
# Epoch 11/100
# 938/938 [==============================] - 6s 6ms/step - loss: 3.3720e-06 - mean_absolute_error: 0.0014 - val_loss: 7.7403e-07 - val_mean_absolute_error: 6.9663e-04
# Epoch 12/100
# 938/938 [==============================] - 7s 7ms/step - loss: 3.3354e-06 - mean_absolute_error: 0.0014 - val_loss: 2.2611e-06 - val_mean_absolute_error: 0.0014
# Epoch 13/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.9446e-06 - mean_absolute_error: 0.0014 - val_loss: 1.0619e-06 - val_mean_absolute_error: 8.3816e-04
# Epoch 14/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.9620e-06 - mean_absolute_error: 0.0014 - val_loss: 3.1146e-06 - val_mean_absolute_error: 0.0016
# Epoch 15/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.8709e-06 - mean_absolute_error: 0.0013 - val_loss: 6.3487e-07 - val_mean_absolute_error: 6.0347e-04
# Epoch 16/100
# 938/938 [==============================] - 6s 7ms/step - loss: 3.2950e-06 - mean_absolute_error: 0.0014 - val_loss: 2.8749e-06 - val_mean_absolute_error: 0.0015
# Epoch 17/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.5244e-06 - mean_absolute_error: 0.0013 - val_loss: 1.5373e-06 - val_mean_absolute_error: 0.0011
# Epoch 18/100
# 938/938 [==============================] - 7s 7ms/step - loss: 2.8836e-06 - mean_absolute_error: 0.0013 - val_loss: 1.3323e-06 - val_mean_absolute_error: 0.0010
# Epoch 19/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.7065e-06 - mean_absolute_error: 0.0013 - val_loss: 1.4003e-06 - val_mean_absolute_error: 0.0010
# Epoch 20/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.5802e-06 - mean_absolute_error: 0.0013 - val_loss: 7.4065e-06 - val_mean_absolute_error: 0.0026
# Epoch 21/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.6779e-06 - mean_absolute_error: 0.0013 - val_loss: 6.0800e-07 - val_mean_absolute_error: 5.9286e-04
# Epoch 22/100
# 938/938 [==============================] - 7s 7ms/step - loss: 2.6725e-06 - mean_absolute_error: 0.0013 - val_loss: 6.6649e-07 - val_mean_absolute_error: 6.3257e-04
# Epoch 23/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.3141e-06 - mean_absolute_error: 0.0012 - val_loss: 3.6960e-06 - val_mean_absolute_error: 0.0018
# Epoch 24/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.5372e-06 - mean_absolute_error: 0.0013 - val_loss: 4.2848e-06 - val_mean_absolute_error: 0.0020
# Epoch 25/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.3686e-06 - mean_absolute_error: 0.0012 - val_loss: 1.6892e-06 - val_mean_absolute_error: 0.0012
# Epoch 26/100
# 938/938 [==============================] - 7s 7ms/step - loss: 2.2038e-06 - mean_absolute_error: 0.0012 - val_loss: 5.0186e-07 - val_mean_absolute_error: 5.1550e-04
# Epoch 27/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.4165e-06 - mean_absolute_error: 0.0012 - val_loss: 9.0640e-07 - val_mean_absolute_error: 7.6585e-04
# Epoch 28/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.2523e-06 - mean_absolute_error: 0.0012 - val_loss: 4.2106e-07 - val_mean_absolute_error: 4.3413e-04
# Epoch 29/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.3833e-06 - mean_absolute_error: 0.0012 - val_loss: 1.5327e-06 - val_mean_absolute_error: 0.0011
# Epoch 30/100
# 938/938 [==============================] - 7s 7ms/step - loss: 2.1952e-06 - mean_absolute_error: 0.0012 - val_loss: 1.6923e-06 - val_mean_absolute_error: 0.0010
# Epoch 31/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.2093e-06 - mean_absolute_error: 0.0012 - val_loss: 6.0750e-06 - val_mean_absolute_error: 0.0023
# Epoch 32/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.0860e-06 - mean_absolute_error: 0.0011 - val_loss: 4.2311e-07 - val_mean_absolute_error: 4.3274e-04
# Epoch 33/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.9800e-06 - mean_absolute_error: 0.0011 - val_loss: 3.5817e-06 - val_mean_absolute_error: 0.0018
# Epoch 34/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.0182e-06 - mean_absolute_error: 0.0011 - val_loss: 2.9246e-06 - val_mean_absolute_error: 0.0016
# Epoch 35/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.1564e-06 - mean_absolute_error: 0.0012 - val_loss: 1.4078e-06 - val_mean_absolute_error: 0.0011
# Epoch 36/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.0997e-06 - mean_absolute_error: 0.0011 - val_loss: 4.4371e-07 - val_mean_absolute_error: 4.7285e-04
# Epoch 37/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.9585e-06 - mean_absolute_error: 0.0011 - val_loss: 4.9380e-07 - val_mean_absolute_error: 4.9461e-04
# Epoch 38/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.1398e-06 - mean_absolute_error: 0.0011 - val_loss: 1.9219e-06 - val_mean_absolute_error: 0.0013
# Epoch 39/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.9278e-06 - mean_absolute_error: 0.0011 - val_loss: 8.1134e-07 - val_mean_absolute_error: 7.2246e-04
# Epoch 40/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.7526e-06 - mean_absolute_error: 0.0010 - val_loss: 1.0085e-06 - val_mean_absolute_error: 8.2472e-04
# Epoch 41/100
# 938/938 [==============================] - 6s 6ms/step - loss: 2.1226e-06 - mean_absolute_error: 0.0011 - val_loss: 1.6376e-06 - val_mean_absolute_error: 0.0011
# Epoch 42/100
# 938/938 [==============================] - 6s 7ms/step - loss: 2.1170e-06 - mean_absolute_error: 0.0011 - val_loss: 2.6513e-06 - val_mean_absolute_error: 0.0015
# Epoch 43/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.7293e-06 - mean_absolute_error: 0.0010 - val_loss: 6.8284e-06 - val_mean_absolute_error: 0.0025
# Epoch 44/100
# 938/938 [==============================] - 7s 7ms/step - loss: 1.8149e-06 - mean_absolute_error: 0.0011 - val_loss: 5.4179e-07 - val_mean_absolute_error: 5.3939e-04
# Epoch 45/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.7932e-06 - mean_absolute_error: 0.0011 - val_loss: 3.0447e-06 - val_mean_absolute_error: 0.0016
# Epoch 46/100
# 938/938 [==============================] - 7s 7ms/step - loss: 2.0731e-06 - mean_absolute_error: 0.0011 - val_loss: 1.0662e-05 - val_mean_absolute_error: 0.0032
# Epoch 47/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.7123e-06 - mean_absolute_error: 0.0010 - val_loss: 2.5911e-06 - val_mean_absolute_error: 0.0015
# Epoch 48/100
# 938/938 [==============================] - 7s 7ms/step - loss: 1.8376e-06 - mean_absolute_error: 0.0011 - val_loss: 7.0887e-07 - val_mean_absolute_error: 6.7584e-04
# Epoch 49/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.9488e-06 - mean_absolute_error: 0.0011 - val_loss: 1.3405e-05 - val_mean_absolute_error: 0.0036
# Epoch 50/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.7093e-06 - mean_absolute_error: 0.0010 - val_loss: 1.9661e-06 - val_mean_absolute_error: 0.0012
# Epoch 51/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.6472e-06 - mean_absolute_error: 0.0010 - val_loss: 8.2267e-07 - val_mean_absolute_error: 7.5322e-04
# Epoch 52/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.8015e-06 - mean_absolute_error: 0.0011 - val_loss: 4.2283e-07 - val_mean_absolute_error: 4.6738e-04
# Epoch 53/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.6934e-06 - mean_absolute_error: 0.0010 - val_loss: 3.8613e-07 - val_mean_absolute_error: 4.3212e-04
# Epoch 54/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.7122e-06 - mean_absolute_error: 0.0010 - val_loss: 2.2184e-06 - val_mean_absolute_error: 0.0014
# Epoch 55/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.6321e-06 - mean_absolute_error: 9.9991e-04 - val_loss: 2.6610e-06 - val_mean_absolute_error: 0.0015
# Epoch 56/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.7568e-06 - mean_absolute_error: 0.0010 - val_loss: 3.9091e-07 - val_mean_absolute_error: 4.2233e-04
# Epoch 57/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.8212e-06 - mean_absolute_error: 0.0011 - val_loss: 3.6655e-06 - val_mean_absolute_error: 0.0018
# Epoch 58/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.4869e-06 - mean_absolute_error: 9.4402e-04 - val_loss: 3.7069e-07 - val_mean_absolute_error: 4.1923e-04
# Epoch 59/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.7762e-06 - mean_absolute_error: 0.0010 - val_loss: 8.6858e-07 - val_mean_absolute_error: 7.6908e-04
# Epoch 60/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.4666e-06 - mean_absolute_error: 9.4599e-04 - val_loss: 1.2850e-06 - val_mean_absolute_error: 9.9060e-04
# Epoch 61/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.6281e-06 - mean_absolute_error: 0.0010 - val_loss: 3.1192e-06 - val_mean_absolute_error: 0.0017
# Epoch 62/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.6229e-06 - mean_absolute_error: 0.0010 - val_loss: 6.4919e-07 - val_mean_absolute_error: 6.0769e-04
# Epoch 63/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.5150e-06 - mean_absolute_error: 9.7050e-04 - val_loss: 3.7512e-06 - val_mean_absolute_error: 0.0019
# Epoch 64/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.7101e-06 - mean_absolute_error: 0.0010 - val_loss: 5.6045e-07 - val_mean_absolute_error: 5.5704e-04
# Epoch 65/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.7250e-06 - mean_absolute_error: 0.0010 - val_loss: 3.6041e-07 - val_mean_absolute_error: 4.0133e-04
# Epoch 66/100
# 938/938 [==============================] - 7s 7ms/step - loss: 1.3466e-06 - mean_absolute_error: 9.1154e-04 - val_loss: 4.8514e-07 - val_mean_absolute_error: 5.2672e-04
# Epoch 67/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.7007e-06 - mean_absolute_error: 0.0010 - val_loss: 4.1518e-07 - val_mean_absolute_error: 4.6784e-04
# Epoch 68/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.4585e-06 - mean_absolute_error: 9.4457e-04 - val_loss: 4.1953e-07 - val_mean_absolute_error: 4.7191e-04
# Epoch 69/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.4872e-06 - mean_absolute_error: 9.5869e-04 - val_loss: 2.8592e-06 - val_mean_absolute_error: 0.0016
# Epoch 70/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.4922e-06 - mean_absolute_error: 9.4705e-04 - val_loss: 3.0219e-06 - val_mean_absolute_error: 0.0016
# Epoch 71/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.4168e-06 - mean_absolute_error: 9.2865e-04 - val_loss: 3.5799e-07 - val_mean_absolute_error: 4.1357e-04
# Epoch 72/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.7057e-06 - mean_absolute_error: 0.0010 - val_loss: 8.8272e-07 - val_mean_absolute_error: 7.8177e-04
# Epoch 73/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.4120e-06 - mean_absolute_error: 9.2852e-04 - val_loss: 8.2445e-07 - val_mean_absolute_error: 7.8292e-04
# Epoch 74/100
# 938/938 [==============================] - 7s 7ms/step - loss: 1.6051e-06 - mean_absolute_error: 9.8849e-04 - val_loss: 3.9192e-07 - val_mean_absolute_error: 4.4432e-04
# Epoch 75/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.4489e-06 - mean_absolute_error: 9.5065e-04 - val_loss: 9.7076e-07 - val_mean_absolute_error: 8.1543e-04
# Epoch 76/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.4371e-06 - mean_absolute_error: 9.3093e-04 - val_loss: 9.2954e-07 - val_mean_absolute_error: 7.6325e-04
# Epoch 77/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.3557e-06 - mean_absolute_error: 9.0423e-04 - val_loss: 1.7327e-06 - val_mean_absolute_error: 0.0012
# Epoch 78/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.4689e-06 - mean_absolute_error: 9.3766e-04 - val_loss: 1.5064e-06 - val_mean_absolute_error: 0.0011
# Epoch 79/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.5298e-06 - mean_absolute_error: 9.6829e-04 - val_loss: 7.1350e-07 - val_mean_absolute_error: 6.8125e-04
# Epoch 80/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.3834e-06 - mean_absolute_error: 9.1681e-04 - val_loss: 5.5335e-07 - val_mean_absolute_error: 5.5350e-04
# Epoch 81/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.3517e-06 - mean_absolute_error: 9.0809e-04 - val_loss: 1.8219e-06 - val_mean_absolute_error: 0.0013
# Epoch 82/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.3192e-06 - mean_absolute_error: 9.0197e-04 - val_loss: 8.0921e-07 - val_mean_absolute_error: 7.3485e-04
# Epoch 83/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.4471e-06 - mean_absolute_error: 9.4227e-04 - val_loss: 8.2867e-07 - val_mean_absolute_error: 7.8859e-04
# Epoch 84/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.3916e-06 - mean_absolute_error: 9.1649e-04 - val_loss: 1.0123e-06 - val_mean_absolute_error: 8.9301e-04
# Epoch 85/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.3694e-06 - mean_absolute_error: 9.1591e-04 - val_loss: 3.9583e-07 - val_mean_absolute_error: 4.5600e-04
# Epoch 86/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.3241e-06 - mean_absolute_error: 8.8942e-04 - val_loss: 8.8830e-07 - val_mean_absolute_error: 8.2501e-04
# Epoch 87/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.2926e-06 - mean_absolute_error: 8.9144e-04 - val_loss: 7.8545e-07 - val_mean_absolute_error: 7.3154e-04
# Epoch 88/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.3420e-06 - mean_absolute_error: 9.0269e-04 - val_loss: 1.6412e-06 - val_mean_absolute_error: 0.0012
# Epoch 89/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.3519e-06 - mean_absolute_error: 8.9889e-04 - val_loss: 4.6868e-07 - val_mean_absolute_error: 5.0512e-04
# Epoch 90/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.2666e-06 - mean_absolute_error: 8.7696e-04 - val_loss: 3.3139e-07 - val_mean_absolute_error: 3.8288e-04
# Epoch 91/100
# 938/938 [==============================] - 7s 7ms/step - loss: 1.3011e-06 - mean_absolute_error: 8.9809e-04 - val_loss: 1.2169e-06 - val_mean_absolute_error: 9.9988e-04
# Epoch 92/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.2923e-06 - mean_absolute_error: 8.9074e-04 - val_loss: 5.7664e-07 - val_mean_absolute_error: 6.1632e-04
# Epoch 93/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.2830e-06 - mean_absolute_error: 8.8294e-04 - val_loss: 1.8895e-06 - val_mean_absolute_error: 0.0013
# Epoch 94/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.3612e-06 - mean_absolute_error: 9.0833e-04 - val_loss: 4.3614e-06 - val_mean_absolute_error: 0.0020
# Epoch 95/100
# 938/938 [==============================] - 7s 7ms/step - loss: 1.2944e-06 - mean_absolute_error: 8.7502e-04 - val_loss: 1.8564e-06 - val_mean_absolute_error: 0.0013
# Epoch 96/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.2682e-06 - mean_absolute_error: 8.8159e-04 - val_loss: 9.0895e-07 - val_mean_absolute_error: 7.9329e-04
# Epoch 97/100
# 938/938 [==============================] - 7s 7ms/step - loss: 1.3539e-06 - mean_absolute_error: 8.9597e-04 - val_loss: 2.3430e-06 - val_mean_absolute_error: 0.0014
# Epoch 98/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.1766e-06 - mean_absolute_error: 8.4311e-04 - val_loss: 7.0497e-07 - val_mean_absolute_error: 7.0014e-04
# Epoch 99/100
# 938/938 [==============================] - 6s 6ms/step - loss: 1.2831e-06 - mean_absolute_error: 8.8956e-04 - val_loss: 9.0049e-07 - val_mean_absolute_error: 8.0489e-04
# Epoch 100/100
# 938/938 [==============================] - 6s 7ms/step - loss: 1.2834e-06 - mean_absolute_error: 8.9493e-04 - val_loss: 8.8161e-07 - val_mean_absolute_error: 8.2112e-04

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 938/938 [==============================] - 2s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 118/118 [==============================] - 0s 2ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 118/118 [==============================] - 0s 3ms/step

# %%
print(y_test.shape,' ',test_predictions.shape)
y_test=np.array(y_test).flatten()
test_predictions=np.array(test_predictions).flatten()
from sklearn.metrics import mean_squared_error as mse,accuracy_score, f1_score
sum=0
for i in range(len(y_test)):
    sum+=abs(y_test[i]-test_predictions[i])
sum=sum/len(y_test)
print((1-sum*100)*100)
# Out:
# (3750,)   (3750,)
# 93.13107967376709

# %% [markdown]
# CALCULATING EMA based on Predicted 'close' Values

# %%
pred_7EMA=[]
pred_21EMA=[]
prev_EMA=_7EMA[dates_test[0]-1]
for i in range(len(dates_test)):
    pred_7EMA.append(0.25*test_predictions[i]+prev_EMA*0.75)
    prev_EMA=pred_7EMA[-1]
prev_EMA=_21EMA[dates_test[0]-1]
for i in range(len(dates_test)):
    pred_21EMA.append((2/22.0)*test_predictions[i]+prev_EMA*(1-2/22))
    prev_EMA=pred_21EMA[-1]

# %%
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(dates_test,pred_7EMA)
plt.plot(dates_test,pred_21EMA)
plt.legend(['Testing Predictions', 'Testing Observations','Predicted 7EMA','Predicted 21EMA'])

# %%
import joblib
joblib.dump(model,'SBIN_model_1min.pkl')
# Out:
# ['SBIN_model_1min.pkl']
